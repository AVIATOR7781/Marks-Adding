# %% [markdown]
# <a href="https://colab.research.google.com/github/AVIATOR7781/Marks-Adding/blob/main/Marks_Adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MARKS ADDED**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import csv

def process_csv(input_file, output_file):
  roll_marks = {}
  with open(input_file, 'r') as csvfile:
    csv_reader = csv.reader(csvfile)
    next(csv_reader, None)
    for row in csv_reader:
      roll_number = row[0]
      mark = int(row[1])
      if roll_number in roll_marks:
        roll_marks[roll_number] += mark
      else:
        roll_marks[roll_number] = mark

  with open(output_file, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['Roll Num', 'Marks', 'Add Marks'])
    for roll_number, total_marks in roll_marks.items():
      csv_writer.writerow([roll_number, '', total_marks])

process_csv('input.csv', 'output.csv')
